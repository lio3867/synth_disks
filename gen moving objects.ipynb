# %%
# %matplotlib
from gen_mov_obj import GEN_MOV_OBJ as GMO
# Out:
# Using matplotlib backend: <object object at 0x0000025050593F20>

# %%
gmo = GMO(nb_objs=50)
for j in range(3):
    gmo.make_images(j,'random', nb_time_pts=3)
    gmo.make_masks(j,arrsize=40)
# Out:
# images folder yet exists
# masks folder yet exists
# self.lobjs_centers = [[384, 69], [13, 393], [201, 26], [204, 439], [35, 212], [407, 403], [354, 503], [419, 66], [349, 463], [15, 157], [109, 400], [271, 319], [321, 178], [249, 462], [369, 321], [342, 83], [463, 237], [168, 187], [424, 89], [319, 334], [271, 290], [182, 389], [280, 279], [355, 92], [298, 464], [290, 384], [213, 95], [209, 496], [411, 127], [321, 337], [34, 416], [146, 204], [205, 346], [251, 475], [50, 412], [7, 385], [174, 122], [429, 188], [392, 390], [181, 155], [110, 472], [39, 13], [405, 46], [1, 84], [36, 408], [218, 294], [233, 458], [485, 470], [84, 132], [129, 47]]
# time point num 0
# random
# time point num 1
# random
# time point num 2
# random
# create the composite image..
# using x=[384, 379, 379.23905353748177]
# using y=[69, 77, 76.02899361164951]
# using x=[13, 3, 6.739116928979202]
# using y=[393, 386, 393.072411511742]
# using x=[201, 195, 200.9893109552385]
# using y=[26, 16, 21.30359823906942]
# using x=[204, 194, 202.80205217701183]
# using y=[439, 436, 434.1228006304174]
# using x=[35, 36, 37.875054237602534]
# using y=[212, 210, 203.25580459906084]
# using x=[407, 414, 416.61105127705423]
# using y=[403, 393, 391.52270137460516]
# using x=[354, 346, 350.44282163144953]
# using y=[503, 504, 501.70623977906934]
# using x=[419, 412, 418.3858158047336]
# using y=[66, 68, 65.13270920414165]
# using x=[349, 347, 353.6363552426695]
# using y=[463, 468, 461.9206259291689]
# using x=[15, 10, 10.99381544456521]
# using y=[157, 159, 159.11104441518444]
# using x=[109, 117, 120.72330473135202]
# using y=[400, 400, 401.461848787492]
# using x=[271, 276, 280.83280080624405]
# using y=[319, 319, 320.2821998156164]
# using x=[321, 312, 313.6653344293454]
# using y=[178, 171, 172.1075473978285]
# using x=[249, 251, 253.73305834315212]
# using y=[462, 454, 449.81306889321945]
# using x=[369, 362, 368.56690389531764]
# using y=[321, 319, 325.1543296328408]
# using x=[342, 334, 334.618755851112]
# using y=[83, 92, 91.21441665196194]
# using x=[463, 465, 467.92209842590967]
# using y=[237, 236, 233.2684545053585]
# using x=[168, 165, 165.8342392406146]
# using y=[187, 192, 191.44859734366005]
# using x=[424, 428, 433.83484820280916]
# using y=[89, 92, 97.47307467975497]
# using x=[319, 318, 323.92858217199074]
# using y=[334, 331, 336.37139771660543]
# using x=[271, 274, 275.53907694538555]
# using y=[290, 284, 280.30794878743774]
# using x=[182, 177, 179.7521973933771]
# using y=[389, 384, 388.1743753434362]
# using x=[280, 283, 290.18281743101846]
# using y=[279, 275, 271.47762384849983]
# using x=[355, 350, 352.91998481551695]
# using y=[92, 92, 91.31174955346869]
# using x=[298, 307, 311.78016860008006]
# using y=[464, 461, 459.53371620932086]
# using x=[290, 292, 293.9190767500317]
# using y=[384, 387, 395.79301679899953]
# using x=[213, 208, 208.20684665756477]
# using y=[95, 87, 90.99464822734797]
# using x=[209, 204, 208.9252577708724]
# using y=[496, 500, 499.1387010446651]
# using x=[411, 406, 409.22969051874566]
# using y=[127, 135, 128.78959750474058]
# using x=[321, 311, 312.70307422789364]
# using y=[337, 327, 328.04858865828527]
# using x=[34, 42, 49.07154141085308]
# using y=[416, 413, 407.4328371611215]
# using x=[146, 140, 140.98297033403225]
# using y=[204, 205, 205.18376431212974]
# using x=[205, 200, 208.69473800677824]
# using y=[346, 346, 348.32411940172744]
# using x=[251, 244, 248.14268025318273]
# using y=[475, 476, 473.20032138989313]
# using x=[50, 48, 52.18149763714023]
# using y=[412, 415, 412.25863583035914]
# using x=[7, 7, 9.707876341578938]
# using y=[385, 384, 391.52777561559304]
# using x=[174, 180, 183.13650751929617]
# using y=[122, 128, 134.25798055137585]
# using x=[429, 420, 427.78617418824246]
# using y=[188, 186, 184.16274892561006]
# using x=[392, 394, 395.2146841612494]
# using y=[390, 385, 383.41111913964266]
# using x=[181, 172, 174.58888361614868]
# using y=[155, 156, 154.48418945047976]
# using x=[110, 108, 113.44198209049824]
# using y=[472, 478, 472.136141975909]
# using x=[39, 41, 42.41271436765251]
# using y=[13, 6, 3.353447881596102]
# using x=[405, 398, 405.7418107491729]
# using y=[46, 48, 45.9839726380848]
# using x=[1, 4, 9.48805718833028]
# using y=[84, 81, 78.57487561192909]
# using x=[36, 45, 51.530553147608586]
# using y=[408, 405, 402.4797072419539]
# using x=[218, 220, 220.43465792930078]
# using y=[294, 302, 303.9521968354897]
# using x=[233, 226, 227.67932585428235]
# using y=[458, 466, 464.91378424098207]
# using x=[485, 482, 482.01459432140064]
# using y=[470, 464, 466.9999645007538]
# using x=[84, 85, 84.44277770286656]
# using y=[132, 127, 123.03900223282349]
# using x=[129, 119, 122.57953733110708]
# using y=[47, 47, 45.21480743469763]
# self.lobjs_centers = [[123, 378], [336, 102], [104, 445], [479, 472], [240, 51], [401, 151], [157, 483], [376, 484], [504, 248], [239, 135], [355, 12], [362, 422], [3, 4], [136, 280], [213, 182], [501, 459], [79, 286], [207, 294], [207, 504], [290, 413], [389, 499], [51, 282], [290, 322], [84, 326], [511, 332], [464, 447], [276, 290], [55, 21], [87, 354], [134, 386], [504, 190], [249, 121], [352, 217], [185, 462], [65, 239], [252, 254], [258, 72], [128, 474], [301, 365], [402, 62], [261, 278], [403, 43], [305, 135], [414, 214], [367, 148], [191, 224], [505, 396], [259, 286], [33, 173], [138, 133]]
# time point num 0
# random
# time point num 1
# random
# time point num 2
# C:\Users\Lionel\Desktop\Projects_in_local\tracking\synth_disks\gen_mov_obj.py:176: RuntimeWarning: divide by zero encountered in double_scalars
#   theta = np.arctan(vec_norm[1]/vec_norm[0])
# random
# create the composite image..
# using x=[123, 130, 132.88969210931546]
# using y=[378, 368, 365.23419459951356]
# using x=[336, 332, 334.25307181388666]
# using y=[102, 97, 104.67617531075662]
# using x=[104, 98, 106.12351604750347]
# using y=[445, 445, 441.1259211383926]
# using x=[479, 469, 472.7840448457375]
# using y=[472, 478, 476.70346438327084]
# using x=[240, 241, 241.3185994155157]
# using y=[51, 49, 42.00725415788382]
# using x=[401, 393, 400.5051717486776]
# using y=[151, 151, 153.7699092084131]
# using x=[157, 159, 163.51469477417007]
# using y=[483, 482, 479.8511558697566]
# using x=[376, 379, 379.53327207717075]
# using y=[484, 481, 479.07240541303156]
# using x=[504, 505, 508.4792476267156]
# using y=[248, 242, 237.11176555881434]
# using x=[239, 247, 248.84359190187223]
# using y=[135, 131, 130.2246491765974]
# using x=[355, 360, 361.38100243364806]
# using y=[12, 18, 19.44666246175745]
# using x=[362, 363, 362.6374845475179]
# using y=[422, 425, 431.9906067366654]
# using x=[3, 2, 2.422679752394931]
# using y=[4, 7, 7]
# using x=[136, 136, 135.3068720011137]
# using y=[280, 288, 282.0401700043407]
# using x=[213, 206, 207.59506853368867]
# using y=[182, 186, 184.79345270592643]
# using x=[501, 503, 503.7293312146655]
# using y=[459, 467, 472.9555080370456]
# using x=[79, 71, 72.98048561106455]
# using y=[286, 280, 280.27870547961294]
# using x=[207, 213, 213.76161103746134]
# using y=[294, 291, 290.35196556602517]
# using x=[207, 210, 212.68603240844286]
# using y=[504, 509, 511.9639888496407]
# using x=[290, 285, 288.4463059970097]
# using y=[413, 404, 408.91151452965124]
# using x=[389, 381, 386.9029711438413]
# using y=[499, 501, 502.07467747486277]
# using x=[51, 58, 65.99552970916116]
# using y=[282, 285, 284.73259642874257]
# using x=[290, 293, 300.3196296949626]
# using y=[322, 326, 331.2366994499037]
# using x=[84, 75, 78.58086000553676]
# using y=[326, 323, 324.78253797175466]
# using x=[511, 503, 504.3013816078414]
# using y=[332, 335, 333.4813144134574]
# using x=[464, 466, 470.9970731713596]
# using y=[447, 449, 452.32103292968895]
# using x=[276, 276, 273.7990674738824]
# using y=[290, 286, 291.58174668141413]
# using x=[55, 48, 51.599116561663365]
# using y=[21, 26, 22.529213349172778]
# using x=[87, 83, 86.74277262406277]
# using y=[354, 351, 352.4112593966264]
# using x=[134, 138, 139.18283933059138]
# using y=[386, 377, 373.17888875875013]
# using x=[504, 497, 505.1240314001446]
# using y=[190, 180, 183.8729980389183]
# using x=[249, 245, 245.99962639548684]
# using y=[121, 120, 120.02733257115597]
# using x=[352, 350, 350.71406751878897]
# using y=[217, 222, 220.13181703823994]
# using x=[185, 184, 183.989162797466]
# using y=[462, 468, 467.00005872420365]
# using x=[65, 62, 64.71029134141031]
# using y=[239, 241, 239.71379595527137]
# using x=[252, 249, 251.33782670658502]
# using y=[254, 261, 257.75430033891337]
# using x=[258, 256, 255.49667105599374]
# using y=[72, 78, 74.03179385942141]
# using x=[128, 124, 125.22304491837207]
# using y=[474, 479, 473.1259757297365]
# using x=[301, 302, 304.8379274036995]
# using y=[365, 365, 364.02728829999245]
# using x=[402, 407, 408.2647652016605]
# using y=[62, 68, 73.86518277504364]
# using x=[261, 251, 257.85373036754925]
# using y=[278, 278, 276.57649023574356]
# using x=[403, 394, 400.9556994911707]
# using y=[43, 44, 44.78628530987635]
# using x=[305, 298, 299.04385943662413]
# using y=[135, 126, 127.70597698594406]
# using x=[414, 422, 429.90164489836434]
# using y=[214, 207, 202.69140302416747]
# using x=[367, 358, 362.8459802173277]
# using y=[148, 153, 149.46213684079376]
# using x=[191, 183, 183.6866611070118]
# using y=[224, 231, 230.27302233588827]
# using x=[505, 505, 508.0051692748222]
# using y=[396, 397, 389.5858946844771]
# using x=[259, 264, 269.1144932582828]
# using y=[286, 289, 296.4055356802179]
# using x=[33, 29, 34.9627216680638]
# using y=[173, 170, 175.33347450628597]
# using x=[138, 144, 148.48609446035735]
# using y=[133, 127, 124.79206963589175]
# self.lobjs_centers = [[82, 107], [122, 288], [345, 100], [71, 175], [150, 217], [75, 311], [211, 466], [312, 176], [293, 410], [78, 237], [125, 317], [219, 289], [260, 307], [351, 132], [260, 66], [425, 445], [37, 282], [57, 386], [268, 381], [405, 29], [163, 271], [238, 123], [76, 59], [137, 437], [59, 330], [298, 470], [479, 104], [122, 54], [269, 322], [238, 203], [289, 465], [197, 429], [337, 370], [163, 61], [208, 171], [171, 422], [255, 339], [192, 212], [99, 253], [3, 195], [377, 393], [297, 410], [187, 259], [270, 99], [496, 401], [494, 409], [298, 485], [190, 32], [144, 123], [330, 21]]
# time point num 0
# random
# time point num 1
# random
# time point num 2
# C:\Users\Lionel\Desktop\Projects_in_local\tracking\synth_disks\gen_mov_obj.py:176: RuntimeWarning: divide by zero encountered in double_scalars
#   theta = np.arctan(vec_norm[1]/vec_norm[0])
# random
# create the composite image..
# using x=[82, 90, 94.98904335341423]
# using y=[107, 109, 109.330826869757]
# using x=[122, 119, 124.14160312940983]
# using y=[288, 279, 285.12894095742837]
# using x=[345, 339, 340.45067672646906]
# using y=[100, 91, 96.82198737848864]
# using x=[71, 79, 83.7592537869512]
# using y=[175, 178, 183.13317673486804]
# using x=[150, 148, 148.73472102145786]
# using y=[217, 214, 214.67836938361626]
# using x=[75, 65, 69.99852305704025]
# using y=[311, 313, 313.1215205671359]
# using x=[211, 205, 207.58183314597414]
# using y=[466, 459, 462.05518209053884]
# using x=[312, 318, 321.86563718695373]
# using y=[176, 176, 177.02803168182726]
# using x=[293, 286, 289.9881924864212]
# using y=[410, 407, 407.3071167388033]
# using x=[78, 83, 88.10692003573193]
# using y=[237, 242, 245.1495027780016]
# using x=[125, 130, 136.8851646277639]
# using y=[317, 325, 330.79607695330117]
# using x=[219, 219, 219.78832019906355]
# using y=[289, 285, 287.89457272559326]
# using x=[260, 258, 257.5953529495254]
# using y=[307, 312, 305.0117054466385]
# using x=[351, 356, 363.07998800751466]
# using y=[132, 137, 142.5564169942013]
# using x=[260, 265, 265.1393842904843]
# using y=[66, 57, 49.00121434094111]
# using x=[425, 424, 424.9592358684426]
# using y=[445, 445, 444.71739329680076]
# using x=[37, 45, 49.88141064426961]
# using y=[282, 275, 273.9174889737229]
# using x=[57, 52, 51.948962057921975]
# using y=[386, 395, 389.00021707655446]
# using x=[268, 273, 280.18994539914615]
# using y=[381, 375, 371.49219653382676]
# using x=[405, 402, 408.30150217301446]
# using y=[29, 32, 27.07140279963008]
# using x=[163, 162, 164.11291120127586]
# using y=[271, 279, 273.3843427583654]
# using x=[238, 241, 242.24523453422063]
# using y=[123, 113, 110.2706427579402]
# using x=[76, 77, 80.71769113383128]
# using y=[59, 51, 45.068830416061914]
# using x=[137, 134, 135.75922879275618]
# using y=[437, 433, 435.43004404378553]
# using x=[59, 54, 54.64556937545766]
# using y=[330, 339, 338.23629836881724]
# using x=[298, 303, 303.91162321827835]
# using y=[470, 464, 463.5889731056296]
# using x=[479, 469, 472.72155293661547]
# using y=[104, 105, 106.4663027449913]
# using x=[122, 123, 122.71032651606708]
# using y=[54, 63, 71.9953370849961]
# using x=[269, 263, 266.53348063107273]
# using y=[322, 313, 314.87470387790546]
# using x=[238, 246, 246.9270613530113]
# using y=[203, 198, 197.62509034721302]
# using x=[289, 288, 289.3292914162194]
# using y=[465, 468, 466.5056826539301]
# using x=[197, 192, 195.86690358181767]
# using y=[429, 430, 426.83029075640593]
# using x=[337, 327, 334.3695025143364]
# using y=[370, 364, 369.1662784178933]
# using x=[163, 165, 167.23573237765817]
# using y=[61, 53, 44.282116040260064]
# using x=[208, 202, 206.55224369410212]
# using y=[171, 170, 172.06810960771125]
# using x=[171, 176, 176.9373564887295]
# using y=[422, 416, 412.11138034605636]
# using x=[255, 252, 258.1117478795814]
# using y=[339, 344, 338.8379715366503]
# using x=[192, 196, 200.25785915564506]
# using y=[212, 207, 201.44386506547139]
# using x=[99, 105, 112.67386386228367]
# using y=[253, 257, 261.70232000433157]
# using x=[3, 5, 5.611056736194544]
# using y=[195, 204, 207.9530506782928]
# using x=[377, 378, 377.8099525604863]
# using y=[393, 398, 399.99095001713613]
# using x=[297, 289, 297.83101118881893]
# using y=[410, 406, 407.73586905697266]
# using x=[187, 180, 181.81871158018865]
# using y=[259, 254, 256.385851669339]
# using x=[270, 275, 282.151273445441]
# using y=[99, 96, 92.41401504346014]
# using x=[496, 491, 493.5407739758815]
# using y=[401, 396, 400.30632878487967]
# using x=[494, 486, 492.8120060079743]
# using y=[409, 405, 406.61138888767505]
# using x=[298, 303, 306.0926915948959]
# using y=[485, 480, 472.62197460706045]
# using x=[190, 191, 190.43842074121724]
# using y=[32, 35, 38.96038239771174]
# using x=[144, 142, 142.11336607824768]
# using y=[123, 128, 126.00321555186777]
# using x=[330, 328, 333.0390526578333]
# using y=[21, 14, 21.457073709678838]
